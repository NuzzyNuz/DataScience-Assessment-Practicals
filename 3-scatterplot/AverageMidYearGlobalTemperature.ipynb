# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
csvData = pd.read_csv('GISSSurfaceTemperatureAnalysis.csv')
csvData
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul    Aug    Sep    Oct  \
# 0    1880 -0.30 -0.21 -0.18 -0.28 -0.14 -0.29 -0.24  -0.08  -0.17  -0.16
# 1    1881 -0.09 -0.14  0.01 -0.03 -0.04 -0.28 -0.06  -0.02  -0.08  -0.19
# 2    1882  0.10  0.09  0.02 -0.20 -0.17 -0.25 -0.10   0.04  -0.01  -0.22
# 3    1883 -0.33 -0.42 -0.17 -0.24 -0.25 -0.11 -0.08  -0.13  -0.18  -0.11
# 4    1884 -0.18 -0.11 -0.34 -0.36 -0.31 -0.38 -0.34  -0.26  -0.23  -0.22
# ..    ...   ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 132  2012  0.46  0.49  0.57  0.69  0.77  0.62  0.57   0.64   0.76   0.79
# 133  2013  0.67  0.56  0.65  0.53  0.62  0.65  0.59   0.66   0.77    0.7
# 134  2014  0.73  0.51  0.77  0.79  0.87  0.66  0.58   0.82   0.91   0.86
# 135  2015  0.82  0.87  0.91  0.74  0.79  0.79  0.73   0.79   0.82   1.07
# 136  2016  1.16  1.32  1.28  1.08  0.94  0.79  0.84    ***    ***    ***
#
#        Nov    Dec    J-D    D-N    DJF   MAM    JJA    SON
# ...

# %%
csvData.describe()
# Out:
#               Year        Jan         Feb         Mar         Apr         May  \
# count   137.000000  137.00000  137.000000  137.000000  137.000000  137.000000
# mean   1948.000000    0.01000    0.023796    0.037226    0.016058    0.013577
# std      39.692569    0.38162    0.380140    0.374413    0.353804    0.339770
# min    1880.000000   -0.70000   -0.600000   -0.620000   -0.590000   -0.540000
# 25%    1914.000000   -0.28000   -0.230000   -0.240000   -0.270000   -0.240000
# 50%    1948.000000   -0.04000   -0.060000   -0.020000   -0.060000   -0.060000
# 75%    1982.000000    0.28000    0.310000    0.260000    0.260000    0.260000
# max    2016.000000    1.16000    1.320000    1.280000    1.080000    0.940000
#
#               Jun         Jul         MAM
# count  137.000000  137.000000  137.000000
# mean    -0.004015    0.028905    0.022190
# std      0.328655    0.304987    0.349941
# min     -0.520000   -0.480000   -0.560000
# 25%     -0.250000   -0.190000   -0.250000
# ...

# %%
y = csvData['Jun']
x1 = csvData['Year']

# %%
plt.scatter(x1,y)
plt.title("Annual Mid Year Global Temperature", size=20)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Temperature (celcius)',fontsize=20)
plt.show()

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# C:\Users\nuzra\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Jun   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     410.6
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           9.06e-43
# Time:                        16:09:34   Log-Likelihood:                 54.217
# No. Observations:                 137   AIC:                            -104.4
# Df Residuals:                     135   BIC:                            -98.59
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
plt.scatter(x1,y)
yhat = 0.0072*x1 + -13.9963
fig = plt.plot(x1,yhat, lw=4, c='orange',label='regression line')
plt.title("Annual Mid Year Global Temperature", size=20)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Temperature (celcius)',fontsize=20)
plt.show()
